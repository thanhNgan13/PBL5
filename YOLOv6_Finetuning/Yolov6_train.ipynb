# %%
  #Clone ma nguon YOLOV6 ve
# %cd /content/drive/MyDrive/yolov6_miai
# !git clone https://github.com/meituan/YOLOv6

# %%
#Cai dat thu vien
# %cd YOLOv6
# !pip install -r requirements.txt

# %%
# Thu nghiem YOLOv6 Pretrain
# !wget https://github.com/meituan/YOLOv6/releases/download/0.4.0/yolov6m_mbla.pt

# %%
# Tai anh tren google ve de thu nghiem nhan dien
# %cd ..
# !mkdir test_images
# %cd test_images
# !wget https://cdn.theculturetrip.com/wp-content/uploads/2017/11/15271255494_fcc90d3f9b_k.jpg
# !wget https://cdnimgen.vietnamplus.vn/t620/uploaded/wbxx/2020_05_13/85896_3585300525545474_a1.jpg
# !wget https://media-cdn-v2.laodong.vn/Storage/NewsPortal/2020/4/22/800234/Chay-Pho-Co-9.jpg
# !wget https://i-vnexpress.vnecdn.net/2019/03/23/chay-1-3737-1553317413.jpg

# %%
# %cd /content/drive/MyDrive/yolov6_miai/YOLOv6
# !python tools/infer.py --weights yolov6m_mbla.pt --source data/images/image2.jpg
# Out:
# /content/drive/MyDrive/yolov6_miai/YOLOv6
# Namespace(weights='yolov6m_mbla.pt', source='data/images/image2.jpg', webcam=False, webcam_addr='0', yaml='data/coco.yaml', img_size=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device='0', save_txt=False, not_save_img=False, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Save directory already existed
# Loading checkpoint from yolov6m_mbla.pt
#
# Fusing model...
# Switch model to deploy modality.
# 100% 1/1 [00:02<00:00,  2.01s/it]
# Results saved to runs/inference/exp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/PBL5
# !mkdir train_images
# %cd train_images
# !unzip ../firedata.zip

# %%
# To chuc lai hinh anh va nhan theo dung cau truc YOLOv6
# %cd /content/drive/MyDrive/PBL5/train_images
# !mkdir images
# !mkdir images/train
# !mkdir labels
# !mkdir labels/train
# !mv *.jpg images/train
# !mv *.txt labels/train
# Out:
# /content/drive/MyDrive/PBL5/train_images

# %%
# Tao Yaml de cho YOLOv6 biet foler train, folder val va so class, tên class
# %cd /content/drive/MyDrive/PBL5/YOLOv6
# !rm data/mydataset2.yaml
# !echo 'train: ../train_images/images/train' >> data/mydataset2.yaml
# !echo 'val: ../train_images/images/train' >> data/mydataset2.yaml
# !echo 'is_coco: False' >> data/mydataset2.yaml
# !echo 'nc: 1' >> data/mydataset2.yaml
# !echo "names: ['fire']" >> data/mydataset2.yaml
# Out:
# /content/drive/MyDrive/PBL5/YOLOv6
# rm: cannot remove 'data/mydataset2.yaml': No such file or directory

# %%
# !pip install addict

# %%
# !pip install wandb -qU
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 22.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00

# %%
import wandb

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# %cd /content/drive/MyDrive/PBL5
# Out:
# /content/drive/MyDrive/PBL5

# %%
# %cd /content/drive/MyDrive/PBL5
# !mkdir data_fire
# %cd data_fire
# !unzip ../yolo_data.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#  extracting: labels/train/fire1-1531-_jpg.rf.536393ba525918b60a8f8f809d86aa51.txt
#  extracting: labels/train/fire1-1547-_jpg.rf.9446d15c30b1f47b6703badae5d11ecc.txt
#  extracting: labels/train/fire1-1552-_jpg.rf.41650527d8758ebc4dd80f454f7312c7.txt
#  extracting: labels/train/fire1-1552-_jpg.rf.ff525b5f5e5dedbd8a816a54d263ae29.txt
#  extracting: labels/train/fire1-1553-_jpg.rf.76a55022526cf6e38cef4f508c42b830.txt
#  extracting: labels/train/fire1-1555-_jpg.rf.9fefebca7def5352f791ca1c9989fa27.txt
#  extracting: labels/train/fire1-1557-_jpg.rf.a8c8eb2b308cd2b389b9e5659caee964.txt
#  extracting: labels/train/fire1-1558-_jpg.rf.5f18cf9801545f735bea2786d389fb6b.txt
#  extracting: labels/train/fire1-1566-_jpg.rf.c02d8cb1c894d43c38ec6717e43b7867.txt
#  extracting: labels/train/fire1-158-_jpg.rf.9ab2192f190c059fde24a644ccc40299.txt
#  extracting: labels/train/fire1-159-_jpg.rf.15247f60d277d0d9e1139980ae68aabd.txt
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jHVqkknmEtHHTFkct7ml")
project = rf.workspace("detection-e83li").project("smokeandfire")
version = project.version(2)
dataset = version.download("mt-yolov6")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to smokeandfire-2 in mt-yolov6:: 100%|██████████| 19707/19707 [02:46<00:00, 118.08it/s]

# %%
# %cd /content/drive/MyDrive/PBL5/YOLOv6
# Out:
# /content/drive/MyDrive/PBL5/YOLOv6

# %%
# !pip install thop
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
# !python tools/eval.py --data /content/drive/MyDrive/PBL5/smokeandfire-2/data.yaml --weights /content/drive/MyDrive/PBL5/weights/main.pt --device 0 --do_pr_metric True --batch-size 16
# Out:
# Namespace(data='/content/smokeandfire-2/data.yaml', weights='/content/drive/MyDrive/PBL5/weights/main.pt', batch_size=16, img_size=640, conf_thres=0.03, iou_thres=0.65, task='val', device='0', half=False, save_dir='runs/val/', name='exp', shrink_size=0, infer_on_rect=True, reproduce_640_eval=False, eval_config_file='./configs/experiment/eval_640_repro.py', do_coco_metric=True, do_pr_metric=True, plot_curve=True, plot_confusion_matrix=False, verbose=False, config_file='', specific_shape=False, height=None, width=None)
# Loading checkpoint from /content/drive/MyDrive/PBL5/weights/main.pt
#
# Fusing model...
# Switch model to deploy modality.
# Model Summary: Params: 34.80M, Gflops: 85.63
# img record infomation path is:/content/smokeandfire-2/images/.train_cache.json
# Val: Checking formats of images with 2 process(es):
# ...

# %%
# !python tools/eval.py --data /content/drive/MyDrive/PBL5/smokeandfire-2/data.yaml --weights /content/drive/MyDrive/PBL5/weights/main.pt --device 0 --do_pr_metric True --batch-size 16
# Out:
# Namespace(data='/content/drive/MyDrive/PBL5/smokeandfire-2/data.yaml', weights='/content/drive/MyDrive/PBL5/weights/main.pt', batch_size=16, img_size=640, conf_thres=0.03, iou_thres=0.65, task='val', device='0', half=False, save_dir='runs/val/', name='exp', shrink_size=0, infer_on_rect=True, reproduce_640_eval=False, eval_config_file='./configs/experiment/eval_640_repro.py', do_coco_metric=True, do_pr_metric=True, plot_curve=True, plot_confusion_matrix=False, verbose=False, config_file='', specific_shape=False, height=None, width=None)
# Loading checkpoint from /content/drive/MyDrive/PBL5/weights/main.pt
#
# Fusing model...
# Switch model to deploy modality.
# Model Summary: Params: 34.80M, Gflops: 85.63
# img record infomation path is:/content/drive/MyDrive/PBL5/smokeandfire-2/images/.test_cache.json
# Val: Checking formats of images with 2 process(es):
# ...

# %%
# !python tools/eval.py --data /content/drive/MyDrive/PBL5/data_fire/data.yaml --batch 16 --weights /content/drive/MyDrive/PBL5/weights/main.pt --task speed
# Out:
# Namespace(data='/content/drive/MyDrive/PBL5/data_fire/data.yaml', weights='/content/drive/MyDrive/PBL5/weights/main.pt', batch_size=16, img_size=640, conf_thres=0.03, iou_thres=0.65, task='speed', device='0', half=False, save_dir='runs/val/', name='exp', shrink_size=0, infer_on_rect=True, reproduce_640_eval=False, eval_config_file='./configs/experiment/eval_640_repro.py', do_coco_metric=True, do_pr_metric=False, plot_curve=True, plot_confusion_matrix=False, verbose=False, config_file='', specific_shape=False, height=None, width=None)
# The best conf_thresh when test the speed of the model is larger than 0.4, while you set it to: 0.03
# Loading checkpoint from /content/drive/MyDrive/PBL5/weights/main.pt
#
# Fusing model...
# Switch model to deploy modality.
# Model Summary: Params: 34.80M, Gflops: 85.63
# img record infomation path is:/content/drive/MyDrive/PBL5/data_fire/images/.test_cache.json
# Speed: Checking formats of images with 2 process(es):
# ...
